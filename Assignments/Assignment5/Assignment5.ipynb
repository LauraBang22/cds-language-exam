# %%
import os
import sys
sys.path.append("..")
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = os.path.join("emissions", "emissions.csv")
data = pd.read_csv(filename)

# %%
data = data.drop(index=2)

# %%
data
# Out:
#              timestamp                     project_name  \
# 0  2024-05-03T13:02:17                      assignment1
# 1  2024-05-03T13:07:37  assignment2_logistic_regression
# 3  2024-05-03T13:09:30       assignment2_neural_network
# 4  2024-05-03T13:10:08           assignment2_vectorizer
# 5  2024-05-03T13:24:22                      assignment3
# 6  2024-05-03T17:34:47                      assignment4
# 7  2024-05-03T17:43:20             assignment4_plotting
#
#                                  run_id    duration     emissions  \
# 0  2dcb2793-6a83-4717-8fb6-27c95ef9d8c0  159.914590  1.484656e-03
# 1  e778ac4c-e00e-4ba4-ba13-b1e927e133c1    0.004226  2.667712e-04
# 3  11242f63-a47c-4eb6-8775-bb319d457c32    0.008452  1.433955e-04
# 4  5a59f3b4-0fda-4da5-94eb-d80b8c0f47f7    0.004595  6.741300e-08
# 5  6af35d92-e2d5-423f-b08b-51dd49f19f69    0.001853  1.594627e-04
# 6  cc678857-7b3e-44f0-9ce1-8a4ac41477de    0.026184  2.419872e-02
# ...

# %%
colors =["#F8B2BC", "#FBB39A", "#FBB39A", "#FBB39A", "#A6C7EA", "#DFCDE3", "#DFCDE3"]

# %%
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(data["project_name"], data["emissions"], color=colors)

# Add labels and title
plt.xlabel("tasks")
plt.ylabel("emissions")
plt.title('Distribution of Values in {}'.format("emissions"))


# Display the plot
plt.xticks(rotation=75)  # Rotate x-axis labels for better readability if many categories
plt.tight_layout()
plt.show()

# %%
filename = os.path.join("emissions", "emissions_base_2dcb2793-6a83-4717-8fb6-27c95ef9d8c0.csv")
data_assignment1 = pd.read_csv(filename)

# %%
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(data_assignment1["task_name"], data_assignment1["emissions"], color='lightblue')

# Add labels and title
plt.xlabel("tasks")
plt.ylabel("emissions")
plt.title('Distribution of Values in {}'.format("emissions"))


# Display the plot
plt.xticks(rotation=75)  # Rotate x-axis labels for better readability if many categories
plt.tight_layout()
plt.show()

# %%
filename = os.path.join("emissions", "emissions_base_e778ac4c-e00e-4ba4-ba13-b1e927e133c1.csv")
data_logistic = pd.read_csv(filename)

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(data_logistic["task_name"], data_logistic["emissions"], color='lightgreen')

# Add labels and title
plt.xlabel("tasks")
plt.ylabel("emissions")
plt.title('Distribution of Values in {}'.format("emissions"))


# Display the plot
plt.xticks(rotation=75)  # Rotate x-axis labels for better readability if many categories
plt.tight_layout()
plt.show()

# %%
filename = os.path.join("emissions", "emissions_base_11242f63-a47c-4eb6-8775-bb319d457c32.csv")
data_neural = pd.read_csv(filename)

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(data_neural["task_name"], data_neural["emissions"], color='#CEB4D9')

# Add labels and title
plt.xlabel("tasks")
plt.ylabel("emissions")
plt.title('Distribution of Values in {}'.format("emissions"))


# Display the plot
plt.xticks(rotation=75)  # Rotate x-axis labels for better readability if many categories
plt.tight_layout()
plt.show()

# %%
filename = os.path.join("emissions", "emissions_base_5a59f3b4-0fda-4da5-94eb-d80b8c0f47f7.csv")
data_vectorizer = pd.read_csv(filename)

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(data_vectorizer["task_name"], data_vectorizer["emissions"], color='#F8B2BC')

# Add labels and title
plt.xlabel("tasks")
plt.ylabel("emissions")
plt.title('Distribution of Values in {}'.format("emissions"))


# Display the plot
plt.xticks(rotation=75)  # Rotate x-axis labels for better readability if many categories
plt.tight_layout()
plt.show()

# %%
filename = os.path.join("emissions", "emissions_base_6af35d92-e2d5-423f-b08b-51dd49f19f69.csv")
data_assignment3 = pd.read_csv(filename)

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(data_assignment3["task_name"], data_assignment3["emissions"], color='#9FD5BE')

# Add labels and title
plt.xlabel("tasks")
plt.ylabel("emissions")
plt.title('Distribution of Values in {}'.format("emissions"))


# Display the plot
plt.xticks(rotation=75)  # Rotate x-axis labels for better readability if many categories
plt.tight_layout()
plt.show()

# %%
filename = os.path.join("emissions", "emissions_base_cc678857-7b3e-44f0-9ce1-8a4ac41477de.csv")
data_assignment4_data = pd.read_csv(filename)

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(data_assignment4_data["task_name"], data_assignment4_data["emissions"], color='#A6C7EA')

# Add labels and title
plt.xlabel("tasks")
plt.ylabel("emissions")
plt.title('Distribution of Values in {}'.format("emissions"))


# Display the plot
plt.xticks(rotation=75)  # Rotate x-axis labels for better readability if many categories
plt.tight_layout()
plt.show()

# %%
filename = os.path.join("emissions", "emissions_base_807fc07a-6725-4042-8af2-56c48596af5a.csv")
data_assignment4_plotting = pd.read_csv(filename)

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(data_assignment4_plotting["task_name"], data_assignment4_plotting["emissions"], color='#A6C7EA')

# Add labels and title
plt.xlabel("tasks")
plt.ylabel("emissions")
plt.title('Distribution of Values in {}'.format("emissions"))


# Display the plot
plt.xticks(rotation=75)  # Rotate x-axis labels for better readability if many categories
plt.tight_layout()
plt.show()
